# %%
import ujson

data = {}

with open('./191639.json', 'r') as f:
  x = f.read()
  data = ujson.loads(x)

# %%
for row in data['Workout']:
  print("-------------")
  print(row)
# Out:
# -------------
# Details
# -------------
# workoutData
# -------------
# intervalData
# -------------
# Plans
# -------------
# Tags
# -------------
# Progression
# -------------
# ProgressionId
# -------------
# ProgressionLevel
# -------------
# Alternative
# -------------
# WorkoutLabel
# -------------
# WorkoutLabelId
# -------------
# ExternalProviderType
# -------------
# Alternates
# -------------
# WorkoutDifficultyRating
# -------------
# WorkoutLevel
# -------------
# MemberProgressionLevels
# -------------
# Levels
# -------------
# ProfileName
# -------------
# SecondaryProgressionLevelV1

# %%
for row in data['Workout']['intervalData']:
  print("-------------")
  print(row)
# Out:
# -------------
# {'Start': 0, 'End': 7200, 'Name': 'Workout', 'IsFake': False, 'TestInterval': False, 'StartTargetPowerPercent': 50.0}
# -------------
# {'Start': 0, 'End': 300, 'Name': 'Fake', 'IsFake': True, 'TestInterval': False, 'StartTargetPowerPercent': 50.0}
# -------------
# {'Start': 300, 'End': 600, 'Name': 'Endurance 1', 'IsFake': False, 'TestInterval': False, 'StartTargetPowerPercent': 63.0}
# -------------
# {'Start': 600, 'End': 900, 'Name': 'Tempo 1', 'IsFake': False, 'TestInterval': False, 'StartTargetPowerPercent': 76.0}
# -------------
# {'Start': 900, 'End': 1200, 'Name': 'Sweet Spot 1', 'IsFake': False, 'TestInterval': False, 'StartTargetPowerPercent': 90.0}
# -------------
# {'Start': 1200, 'End': 1500, 'Name': 'Fake', 'IsFake': True, 'TestInterval': False, 'StartTargetPowerPercent': 40.0}
# -------------
# {'Start': 1500, 'End': 1620, 'Name': 'Sweet Spot 2', 'IsFake': False, 'TestInterval': False, 'StartTargetPowerPercent': 85.0}
# -------------
# ...

# %%
for row in data['Workout']['workoutData']:
  print("-------------")
  print(row)
# Out:
# -------------
# {'seconds': 0, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 1000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 2000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 3000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 4000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 5000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 6000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 7000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 8000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 9000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 10000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# -------------
# {'seconds': 11000, 'memberFtpPercent': 144.5, 'ftpPercent': 50.0}
# ...
